# %%
import pandas as pd

# %%
df = pd.read_csv('fic_etiq_edition_40-mars-2015.csv')

# %%
df.drop(['lib_mrq_doss',])
# Out:
#       lib_mrq_doss lib_mod_doss     mrq_utac mod_utac  \
# 0      ALFA ROMEO           159  ALFA ROMEO       159
# 1      ALFA ROMEO           159  ALFA ROMEO       159
# 2      ALFA ROMEO           159  ALFA ROMEO       159
# 3      ALFA ROMEO           159  ALFA ROMEO       159
# 4      ALFA ROMEO           159  ALFA ROMEO       159
# ...            ...          ...          ...      ...
# 20875       VOLVO         XC90        VOLVO     XC90
# 20876       VOLVO         XC90        VOLVO     XC90
# 20877       VOLVO         XC90        VOLVO     XC90
# 20878       VOLVO         XC90        VOLVO     XC90
# 20879       VOLVO         XC90        VOLVO     XC90
#
#                                                    dscom              cnit  \
# 0                                  159 1750 Tbi (200ch)   M10ALFVP000G340
# 1                              159 2.0 JTDm (170ch) ECO   M10ALFVP000U221
# 2                                  159 2.0 JTDm (136ch)   M10ALFVP000E302
# ...
